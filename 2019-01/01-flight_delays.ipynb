# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
#plt.rcParams['figure.figsize'] = (20, 10)

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Temario
#
# Estos son algunos de los temas que intentaremos revisar a lo largo del analisis propuesto
#
# - Manipulando el Data Frame
#    - Manejo de Indices
#    - Joins

# %%
# carga de un data frame
#flights = pd.read_csv('../data/flight-delays/flights.csv', low_memory=False)
flights = pd.read_csv('../data/flight-delays/flights.csv', low_memory=False)

# por ejemplo se puede usar index_col para indicar un indice
airports = pd.read_csv('../data/flight-delays/airports.csv', sep=',', encoding='utf-8', index_col='IATA_CODE')

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE                object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# dtypes: float64(16), int64(10), object(5)
# memory usage: 1.3+ GB

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 322 entries, ABE to YUM
# Data columns (total 6 columns):
# AIRPORT      322 non-null object
# CITY         322 non-null object
# STATE        322 non-null object
# COUNTRY      322 non-null object
# LATITUDE     319 non-null float64
# LONGITUDE    319 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 17.6+ KB

# %% [markdown]
# # Joins

# %%
airports_with_origin = pd.merge(flights, airports, left_on="ORIGIN_AIRPORT", right_on="IATA_CODE", how="inner")

# %%
airports_with_origin.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AS            108      N309AS
# 2  2015      1    1            4      DL           1560      N3743H
# 3  2015      1    1            4      AS            122      N413AS
# 4  2015      1    1            4      AS            136      N431AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0            ANC                 SEA                    5  ...
# 1            ANC                 SEA                   45  ...
# 2            ANC                 SEA                   45  ...
# 3            ANC                 PDX                   50  ...
# 4            ANC                 SEA                  135  ...
#
#         SECURITY_DELAY        AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0                  nan                  nan                  nan
# 1                  nan                  nan                  nan
# 2                  nan                  nan                  nan
# 3                  nan                  nan                  nan
# 4                  nan                  nan                  nan
#
#          WEATHER_DELAY                                      AIRPORT  \
# 0                  nan  Ted Stevens Anchorage International Airport
# 1                  nan  Ted Stevens Anchorage International Airport
# 2                  nan  Ted Stevens Anchorage International Airport
# 3                  nan  Ted Stevens Anchorage International Airport
# 4                  nan  Ted Stevens Anchorage International Airport
#
#         CITY  STATE  COUNTRY             LATITUDE            LONGITUDE
# 0  Anchorage     AK      USA                61.17              -150.00
# 1  Anchorage     AK      USA                61.17              -150.00
# 2  Anchorage     AK      USA                61.17              -150.00
# 3  Anchorage     AK      USA                61.17              -150.00
# 4  Anchorage     AK      USA                61.17              -150.00
#
# [5 rows x 37 columns]

# %%
airports_with_origin_dest = pd.merge(airports_with_origin, airports, left_on="DESTINATION_AIRPORT", right_on="IATA_CODE", how="inner")

# %%
airports_with_origin_dest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332914 entries, 0 to 5332913
# Data columns (total 43 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE                object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# AIRPORT_x              object
# CITY_x                 object
# STATE_x                object
# COUNTRY_x              object
# LATITUDE_x             float64
# LONGITUDE_x            float64
# AIRPORT_y              object
# CITY_y                 object
# STATE_y                object
# COUNTRY_y              object
# LATITUDE_y             float64
# LONGITUDE_y            float64
# dtypes: float64(20), int64(10), object(13)
# memory usage: 1.7+ GB

# %%
airports_with_origin_dest = pd.merge(airports_with_origin, airports, left_on="DESTINATION_AIRPORT", right_on="IATA_CODE", how="inner",suffixes=("_ORIGIN","_DESTINATION"))

# %%
airports_with_origin_dest.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AS            108      N309AS
# 2  2015      1    1            4      DL           1560      N3743H
# 3  2015      1    1            4      AS            136      N431AS
# 4  2015      1    1            4      AS            134      N464AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  STATE_ORIGIN  \
# 0            ANC                 SEA                    5  ...            AK
# 1            ANC                 SEA                   45  ...            AK
# 2            ANC                 SEA                   45  ...            AK
# 3            ANC                 SEA                  135  ...            AK
# 4            ANC                 SEA                  155  ...            AK
#
#    COUNTRY_ORIGIN      LATITUDE_ORIGIN     LONGITUDE_ORIGIN  \
# 0             USA                61.17              -150.00
# 1             USA                61.17              -150.00
# 2             USA                61.17              -150.00
# 3             USA                61.17              -150.00
# 4             USA                61.17              -150.00
#
#                     AIRPORT_DESTINATION  CITY_DESTINATION  STATE_DESTINATION  \
# 0  Seattle-Tacoma International Airport           Seattle                 WA
# 1  Seattle-Tacoma International Airport           Seattle                 WA
# 2  Seattle-Tacoma International Airport           Seattle                 WA
# 3  Seattle-Tacoma International Airport           Seattle                 WA
# 4  Seattle-Tacoma International Airport           Seattle                 WA
#
#    COUNTRY_DESTINATION  LATITUDE_DESTINATION  LONGITUDE_DESTINATION
# 0                  USA                 47.45                -122.31
# 1                  USA                 47.45                -122.31
# 2                  USA                 47.45                -122.31
# 3                  USA                 47.45                -122.31
# 4                  USA                 47.45                -122.31
#
# [5 rows x 43 columns]

# %%
airports_with_origin_dest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332914 entries, 0 to 5332913
# Data columns (total 43 columns):
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                  object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER              object
# ORIGIN_AIRPORT           object
# DESTINATION_AIRPORT      object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME           float64
# DEPARTURE_DELAY          float64
# TAXI_OUT                 float64
# WHEELS_OFF               float64
# SCHEDULED_TIME           float64
# ELAPSED_TIME             float64
# AIR_TIME                 float64
# DISTANCE                 int64
# WHEELS_ON                float64
# TAXI_IN                  float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME             float64
# ARRIVAL_DELAY            float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON      object
# AIR_SYSTEM_DELAY         float64
# SECURITY_DELAY           float64
# AIRLINE_DELAY            float64
# LATE_AIRCRAFT_DELAY      float64
# WEATHER_DELAY            float64
# AIRPORT_ORIGIN           object
# CITY_ORIGIN              object
# STATE_ORIGIN             object
# COUNTRY_ORIGIN           object
# LATITUDE_ORIGIN          float64
# LONGITUDE_ORIGIN         float64
# AIRPORT_DESTINATION      object
# CITY_DESTINATION         object
# STATE_DESTINATION        object
# COUNTRY_DESTINATION      object
# LATITUDE_DESTINATION     float64
# LONGITUDE_DESTINATION    float64
# dtypes: float64(20), int64(10), object(13)
# memory usage: 1.7+ GB
